# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from PIL import Image
import requests
from io import BytesIO
from patsy import dmatrices

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split

import graphviz
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.inspection import DecisionBoundaryDisplay

# %%
df_raw = pd.read_csv("./data/Credit.csv")

# %%
df_raw.shape
# Out:
# (400, 12)

# %%
df_raw.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %%
df = df_raw.astype({ 'Gender': 'category', 'Student': 'category', 'Married': 'category', 'Ethnicity': 'category' }).drop('Unnamed: 0', axis=1)

# %%
df.dtypes
# Out:
# Income        float64
# Limit           int64
# Rating          int64
# Cards           int64
# Age             int64
# Education       int64
# Gender       category
# Student      category
# Married      category
# Ethnicity    category
# Balance         int64
# dtype: object

# %%
df.shape
# Out:
# (400, 11)

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 10))
# Out:
# array([[<AxesSubplot:xlabel='Income', ylabel='Income'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Income'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Income'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Income'>,
#         <AxesSubplot:xlabel='Age', ylabel='Income'>,
#         <AxesSubplot:xlabel='Education', ylabel='Income'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Income'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Age', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Education', ylabel='Limit'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Limit'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Age', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Education', ylabel='Rating'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Rating'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Cards'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Cards'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Cards'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Cards'>,
#         <AxesSubplot:xlabel='Age', ylabel='Cards'>,
#         <AxesSubplot:xlabel='Education', ylabel='Cards'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Cards'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Age'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Age'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Age'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Age'>,
#         <AxesSubplot:xlabel='Age', ylabel='Age'>,
#         <AxesSubplot:xlabel='Education', ylabel='Age'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Age'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Education'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Education'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Education'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Education'>,
#         <AxesSubplot:xlabel='Age', ylabel='Education'>,
#         <AxesSubplot:xlabel='Education', ylabel='Education'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Education'>],
#        [<AxesSubplot:xlabel='Income', ylabel='Balance'>,
#         <AxesSubplot:xlabel='Limit', ylabel='Balance'>,
#         <AxesSubplot:xlabel='Rating', ylabel='Balance'>,
#         <AxesSubplot:xlabel='Cards', ylabel='Balance'>,
#         <AxesSubplot:xlabel='Age', ylabel='Balance'>,
#         <AxesSubplot:xlabel='Education', ylabel='Balance'>,
#         <AxesSubplot:xlabel='Balance', ylabel='Balance'>]], dtype=object)

# %%
def train_model(df, formula, model):
    y, x = dmatrices(formula, data=df, return_type='dataframe') 
    Y = y.values.ravel()
    X = preprocessing.StandardScaler().fit(x.values).transform(x.values)
    
    kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=1)
    cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring='accuracy')
    msg = "mean: %f       std: %f" % (cv_results.mean(), cv_results.std())
    print(msg)

# %%
df['IncomeGt50'] = df.apply(lambda row: 1 if row['Income'] > 50 else 0, axis=1)

# %%
df.dtypes
# Out:
# Income         float64
# Limit            int64
# Rating           int64
# Cards            int64
# Age              int64
# Education        int64
# Gender        category
# Student       category
# Married       category
# Ethnicity     category
# Balance          int64
# IncomeGt50       int64
# dtype: object

# %% [markdown]
# ## Logistic regression

# %%
train_model(df, "IncomeGt50 ~ Limit + Rating + Education + Student + Balance", LogisticRegression())
# Out:
# mean: 0.945000       std: 0.028062

# %%
train_model(df, "Cards ~ Limit + Rating + Education + Gender + Married + Balance", LogisticRegression())
# Out:
# mean: 0.332500       std: 0.040774

# %% [markdown]
# ## KNN

# %%
train_model(df, "IncomeGt50 ~ Limit + Rating + Education + Student + Balance", KNeighborsClassifier(n_neighbors=3))
# Out:
# mean: 0.920000       std: 0.029155

# %%
train_model(df, "Cards ~ Limit + Rating + Education + Gender + Married + Balance", KNeighborsClassifier(n_neighbors=170))
# Out:
# mean: 0.275000       std: 0.041833

# %% [markdown]
# ## Decision trees

# %%
train_model(df, "IncomeGt50 ~ Rating + Balance", DecisionTreeClassifier(max_depth=20))
# Out:
# mean: 0.915000       std: 0.033912

# %%
train_model(df, "Cards ~ Limit + Rating + Education + Married + Balance", DecisionTreeClassifier(max_depth=5))
# Out:
# mean: 0.280000       std: 0.040774

# %% [markdown]
# # Display

# %%
def display_boundaries(df, y_label, x1_label, x2_label, model):    
    X = df[[x1_label, x2_label]]
    y = df[y_label]
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.4, random_state=42
    )
    x_min, x_max = X[x1_label].min() - 0.5, X[x1_label].max() + 0.5
    y_min, y_max = X[x2_label].min() - 0.5, X[x2_label].max() + 0.5

    clf = make_pipeline(preprocessing.StandardScaler(), model)
    clf.fit(X_train, y_train)
    ax = plt.subplot()
    DecisionBoundaryDisplay.from_estimator(
        clf, X_train, cmap=plt.cm.RdBu, alpha=0.8, ax=ax, eps=0.5
    )
    
    cm_bright = ListedColormap(["#FF0000", "#0000FF"])
    
    # Plot the training points
    ax.scatter(
        X_train[x1_label], X_train[x2_label], c=y_train, cmap=cm_bright, edgecolors="k"
    )
    
    # Plot the testing points
    ax.scatter(
        X_test[x1_label],
        X_test[x2_label],
        c=y_test,
        cmap=cm_bright,
        edgecolors="k",
        alpha=0.6,
    )

    ax.set_xlim(x_min, x_max)
    ax.set_ylim(y_min, y_max)
    ax.set_xticks(())
    ax.set_yticks(())

# %% [markdown]
# ## Income

# %%
display_boundaries(df, 'IncomeGt50', 'Balance', 'Rating', LogisticRegression())

# %%
display_boundaries(df, 'IncomeGt50', 'Balance', 'Rating', KNeighborsClassifier(n_neighbors=5))

# %%
display_boundaries(df, 'IncomeGt50', 'Balance', 'Rating', DecisionTreeClassifier(max_depth=20))

# %% [markdown]
# ## Cards

# %%
display_boundaries(df, 'Cards', 'Balance', 'Limit', LogisticRegression())

# %%
display_boundaries(df, 'Cards', 'Balance', 'Limit', KNeighborsClassifier(n_neighbors=5))

# %%
display_boundaries(df, 'Cards', 'Balance', 'Limit', DecisionTreeClassifier(max_depth=20))
