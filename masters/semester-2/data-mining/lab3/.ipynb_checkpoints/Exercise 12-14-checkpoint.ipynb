# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
from PIL import Image
import requests
from io import BytesIO
from patsy import dmatrices

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.neighbors import KNeighborsClassifier
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier

# %%
df_raw = pd.read_csv("./data/Credit.csv")

# %%
df_raw.shape
# Out:
# (400, 12)

# %%
df_raw.head()
# Out:
#    Unnamed: 0   Income  Limit  Rating  Cards  Age  Education  Gender Student  \
# 0           1   14.891   3606     283      2   34         11    Male      No
# 1           2  106.025   6645     483      3   82         15  Female     Yes
# 2           3  104.593   7075     514      4   71         11    Male      No
# 3           4  148.924   9504     681      3   36         11  Female      No
# 4           5   55.882   4897     357      2   68         16    Male      No
#
#   Married  Ethnicity  Balance
# 0     Yes  Caucasian      333
# 1     Yes      Asian      903
# 2      No      Asian      580
# 3      No      Asian      964
# 4     Yes  Caucasian      331

# %%
df = df_raw.astype({ 'Gender': 'category', 'Student': 'category', 'Married': 'category', 'Ethnicity': 'category' }).drop('Unnamed: 0', axis=1)

# %%
df.dtypes
# Out:
# Income        float64
# Limit           int64
# Rating          int64
# Cards           int64
# Age             int64
# Education       int64
# Gender       category
# Student      category
# Married      category
# Ethnicity    category
# Balance         int64
# dtype: object

# %%
df.shape
# Out:
# (400, 11)

# %%
def train_model(df, formula, model):
    y, x = dmatrices(formula, data=df, return_type='dataframe') 
    Y = y.values.ravel()
    X = x.values
#     print(X.shape)
#     print(Y.shape)
    kfold = model_selection.KFold(n_splits=10, shuffle=True, random_state=1)
    cv_results = model_selection.cross_val_score(model, y, x, cv=kfold, scoring='accuracy')
    msg = "%s:     mean: %f       std: %f" % (name, cv_results.mean(), cv_results.std())
    print(msg)

# %% [markdown]
# ## Logistic regression

# %%
df['IncomeGt50'] = df.apply(lambda row: 'Yes' if row['Income'] > 50 else 'No', axis=1)

# %%
df.astype({'IncomeGt50': 'category'})
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0     14.891   3606     283      2   34         11    Male      No     Yes
# 1    106.025   6645     483      3   82         15  Female     Yes     Yes
# 2    104.593   7075     514      4   71         11    Male      No      No
# 3    148.924   9504     681      3   36         11  Female      No      No
# 4     55.882   4897     357      2   68         16    Male      No     Yes
# ..       ...    ...     ...    ...  ...        ...     ...     ...     ...
# 395   12.096   4100     307      3   32         13    Male      No     Yes
# 396   13.364   3838     296      5   65         17    Male      No      No
# 397   57.872   4171     321      5   67         12  Female      No     Yes
# 398   37.728   2525     192      1   44         13    Male      No     Yes
# 399   18.701   5524     415      5   64          7  Female      No      No
#
#             Ethnicity  Balance IncomeGt50
# ...

# %%
train_model(df, "IncomeGt50 ~ Balance", LogisticRegression())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [129], line 1
# ----> 1 train_model(df, "IncomeGt50 ~ Balance", LogisticRegression())
#
# Cell In [123], line 8, in train_model(df, formula, model)
#       5 #     print(X.shape)
#       6 #     print(Y.shape)
#       7     kfold = model_selection.KFold(n_splits=10, shuffle=True, random_state=1)
# ----> 8     cv_results = model_selection.cross_val_score(model, y, x, cv=kfold, scoring='accuracy')
#       9     msg = "%s:     mean: %f       std: %f" % (name, cv_results.mean(), cv_results.std())
#      10     print(msg)
#
# File /usr/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:515, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     512 # To ensure multimetric format is not supported
# ...
